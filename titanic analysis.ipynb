# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sea

# %%
t=pd.read_csv('titanic.csv')

# %%
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# as can seen from info there are total 891 entries and 12 coloumns .
# data types are dtypes: float64(2), int64(5), object(5)

# %%
t.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # there are 891 entries and some null values in age and cabin

# %%
age=t['Age'].mean()
age
# Out:
# 29.69911764705882

# %%
t['Age'].fillna(age,inplace=True)

# %% [markdown]
# # to fill  nullvalues i fnd avg of age from given database and fill in null values

# %%
t.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
t.drop('Cabin',axis=1,inplace=True)

# %%
# here in cabin column total 687 null values so we have to drop this cloumn

# %%
t.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
t['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
t['Embarked'].fillna('S',inplace=True)

# %%
t.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
t.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Embarked
# 0      0  A/5 21171   7.2500        S
# 1      0   PC 17599  71.2833        C

# %%
# Find the avg age of male who travelled in titanic
t['Age'].loc[(t['Sex']=='male') & (t['Age'])].mean()
# Out:
# 30.505824243042102

# %%
# Find the avg age of female who travelled in titanic
t['Age'].loc[(t['Sex']=='female') & (t['Age'])].mean()
# Out:
# 28.21673004870738

# %%
#max fare
t['Fare'].max()
# Out:
# 512.3292

# %%
#min fare
t['Fare'].min()
# Out:
# 0.0

# %%
#find the % of pclass
t['Pclass'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # as can seen from chart is shows pclass 3 had max num of passenger about 55%

# %%
t.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %%
#find the total num of % female and male survved
t['Survived'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # as can seen 61.6% female survved

# %%
t.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
#import model
from sklearn.preprocessing import LabelEncoder
#init lable encoder
le=LabelEncoder()

#transfer output
t['Embarked']=le.fit_transform(t['Embarked'])

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  Embarked
# 0      0         A/5 21171   7.2500         2
# 1      0          PC 17599  71.2833         0
# 2      0  STON/O2. 3101282   7.9250         2
# 3      0            113803  53.1000         2
# 4      0            373450   8.0500         2

# %%
#s=2 c=0

# %%
t['Sex']=le.fit_transform(t['Sex'])

# %%
#male=1 female=0

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  Embarked
# 0         A/5 21171   7.2500         2
# 1          PC 17599  71.2833         0
# 2  STON/O2. 3101282   7.9250         2
# 3            113803  53.1000         2
# 4            373450   8.0500         2

# %%
sea.pairplot(t)

# %%
sea.boxplot(data=t,x='SibSp',y='Age')
# Out:
# <Axes: xlabel='SibSp', ylabel='Age'>

# %%
t.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)

# %%
#import model
from sklearn.preprocessing import LabelEncoder
#init lable encoder
le=LabelEncoder()

# %%
t
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.000000      1      0   7.2500         2
# 1           1       1    0  38.000000      1      0  71.2833         0
# 2           1       3    0  26.000000      0      0   7.9250         2
# 3           1       1    0  35.000000      1      0  53.1000         2
# 4           0       3    1  35.000000      0      0   8.0500         2
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    1  27.000000      0      0  13.0000         2
# 887         1       1    0  19.000000      0      0  30.0000         2
# 888         0       3    0  29.699118      1      2  23.4500         2
# 889         1       1    1  26.000000      0      0  30.0000         0
# 890         0       3    1  32.000000      0      0   7.7500         1
#
# [891 rows x 8 columns]

# %%
x=t.iloc[:,1:]
x
# Out:
#      Pclass  Sex  Age  SibSp  Parch  Fare  Embarked
# 0         3    1   28      1      0    18         2
# 1         1    0   52      1      0   207         0
# 2         3    0   34      0      0    41         2
# 3         1    0   48      1      0   189         2
# 4         3    1   48      0      0    43         2
# ..      ...  ...  ...    ...    ...   ...       ...
# 886       2    1   35      0      0    85         2
# 887       1    0   24      0      0   153         2
# 888       3    0   39      1      2   131         2
# 889       1    1   34      0      0   153         0
# 890       3    1   43      0      0    30         1
#
# [891 rows x 7 columns]

# %%
y=t['Survived']
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
x
# Out:
#      Pclass  Sex  Age  SibSp  Parch  Fare  Embarked
# 0         3    1   28      1      0    18         2
# 1         1    0   52      1      0   207         0
# 2         3    0   34      0      0    41         2
# 3         1    0   48      1      0   189         2
# 4         3    1   48      0      0    43         2
# ..      ...  ...  ...    ...    ...   ...       ...
# 886       2    1   35      0      0    85         2
# 887       1    0   24      0      0   153         2
# 888       3    0   39      1      2   131         2
# 889       1    1   34      0      0   153         0
# 890       3    1   43      0      0    30         1
#
# [891 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.30,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
lr=LogisticRegression()
kn=KNeighborsClassifier()
lr.fit(xtrain,ytrain)
ypred=lr.predict(xtest)

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81       153
#            1       0.76      0.68      0.72       115
#
#     accuracy                           0.77       268
#    macro avg       0.77      0.76      0.76       268
# weighted avg       0.77      0.77      0.77       268

# %%
def runmodel(ob):
    ob.fit(xtrain,ytrain)
    ypred=ob.predict(xtest)
    print(classification_report(ytest,ypred))

# %%
runmodel(lr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81       153
#            1       0.76      0.68      0.72       115
#
#     accuracy                           0.77       268
#    macro avg       0.77      0.76      0.76       268
# weighted avg       0.77      0.77      0.77       268

# %%
runmodel(kn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.79      0.73       153
#            1       0.64      0.49      0.55       115
#
#     accuracy                           0.66       268
#    macro avg       0.65      0.64      0.64       268
# weighted avg       0.66      0.66      0.65       268

# %%
# As seen Lr model gives better performance

# %%
t
# Out:
#      Survived  Pclass  Sex  Age  SibSp  Parch  Fare  Embarked
# 0           0       3    1   28      1      0    18         2
# 1           1       1    0   52      1      0   207         0
# 2           1       3    0   34      0      0    41         2
# 3           1       1    0   48      1      0   189         2
# 4           0       3    1   48      0      0    43         2
# ..        ...     ...  ...  ...    ...    ...   ...       ...
# 886         0       2    1   35      0      0    85         2
# 887         1       1    0   24      0      0   153         2
# 888         0       3    0   39      1      2   131         2
# 889         1       1    1   34      0      0   153         0
# 890         0       3    1   43      0      0    30         1
#
# [891 rows x 8 columns]

# %%
try:
   

    Pclass = int(input('Enter Pclass (1 to 3): '))
    if Pclass not in [1, 2, 3]:
        raise ValueError('Pclass must be 1, 2, or 3')

    Sex = int(input('Enter Sex (1 or 2): '))
    if Sex not in [1, 2]:
        raise ValueError('Sex must be 1 or 2')

    Age = int(input('Enter Age: '))

    SibSp = int(input('Enter SibSp (0 or 1): '))
    if SibSp not in [0, 1]:
        raise ValueError('SibSp must be 0 or 1')

    Parch = int(input('Enter Parch: '))

    Fare = float(input('Enter Fare: '))

    Embarked = int(input('Enter Embark (1, 2, or 3): '))
    if Embarked not in [1, 2, 3]:
        raise ValueError('Embarked must be 1, 2, or 3')

    res = lr.predict([[ Pclass, Sex, Age, SibSp, Parch, Fare, Embarked]])
    
    if res[0] == 1:
        print("Passenger survived")
    else:
        print("Passenger will not survive")
except ValueError as e:
    print(f"Input error: {e}")
# Out:
# Enter Pclass (1 to 3):  1
# Enter Sex (1 or 2):  2
# Enter Age:  3
# Enter SibSp (0 or 1):  1
# Enter Parch:  2
# Enter Fare:  2
# Enter Embark (1, 2, or 3):  1
# Passenger will not survive
# C:\Users\Laptop_User\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
